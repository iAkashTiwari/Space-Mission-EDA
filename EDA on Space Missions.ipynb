# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Space Missions.xlsx')

# %%
df
# Out:
#         Sr Organisation                                           Location  \
# 0        0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1        1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2        2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3        3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4        4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...    ...          ...                                                ...
# 4319  4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320  4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321  4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322  4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323  4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#       Year            Year.1                        Date  \
# ...

# %%
print(df.head())
# Out:
#    Sr Organisation                                           Location  Year  \
# 0   0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA  2020
# 1   1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...  2020
# 2   2       SpaceX                      Pad A, Boca Chica, Texas, USA  2020
# 3   3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan  2020
# 4   4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA  2020
#
#              Year.1                        Date  \
# 0  Fri Aug 07, 2020  Fri Aug 07, 2020 05:12 UTC
# 1  Thu Aug 06, 2020  Thu Aug 06, 2020 04:01 UTC
# 2  Tue Aug 04, 2020  Tue Aug 04, 2020 23:57 UTC
# 3  Thu Jul 30, 2020  Thu Jul 30, 2020 21:25 UTC
# 4  Thu Jul 30, 2020  Thu Jul 30, 2020 11:50 UTC
#
#                                          Detail Rocket_Status Mission_Status
# 0  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky  StatusActive        Success
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sr              4324 non-null   int64
#  1   Organisation    4324 non-null   object
#  2   Location        4324 non-null   object
#  3   Year            4324 non-null   int64
#  4   Year.1          4324 non-null   object
#  5   Date            4324 non-null   object
#  6   Detail          4324 non-null   object
#  7   Rocket_Status   4324 non-null   object
#  8   Mission_Status  4324 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 304.2+ KB
# None

# %%
print(df.describe())
# Out:
#                 Sr         Year
# count  4324.000000  4324.000000
# mean   2161.500000  1987.386679
# std    1248.375611    18.072562
# min       0.000000  1957.000000
# 25%    1080.750000  1972.000000
# 50%    2161.500000  1984.000000
# 75%    3242.250000  2002.000000
# max    4323.000000  2020.000000

# %%
# Number of space mission by organizations
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Organisation')
plt.title('Number of Space Missions by Organisation')
plt.xticks(rotation=90)
plt.show()

# %%
# Pie chart for rocket status
plt.figure(figsize=(6, 6))
df['Rocket_Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Percentage of Rocket Status')
plt.show()

# %%
# Mission status by orginization
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Organisation', hue='Mission_Status')
plt.title('Mission Status by Organisation')
plt.xticks(rotation=90)
plt.legend(title='Mission Status', loc='upper right')
plt.show()

# %%
# Mission status
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Mission_Status')
plt.title('Mission Status')
plt.show()

# %%
# Box Plot of Mission Years by Organisation
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Organisation', y='Year')
plt.title('Mission Years by Organisation')
plt.xticks(rotation=90)
plt.show()

# %%
# Line chart of Number of Space Missions Over the Years
plt.figure(figsize=(10, 6))
missions_by_year = df['Year'].value_counts().sort_index()
missions_by_year.plot(kind='line', marker='o')
plt.title('Number of Space Missions Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Missions')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Rocket_Status', hue='Mission_Status')
plt.title('Mission Status Distribution for each Rocket Status')
plt.legend(title='Mission Status', loc='upper right')
plt.show()
